# %%
import pandas as pd
import re

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/CADE
# Out:
# /content/drive/My Drive/CADE

# %% [markdown]
# ## Classification

# %%
import pandas as pd
import re

df = pd.read_csv('/content/drive/My Drive/CADE/results/qwen3-0.6B+lora/results_classification.csv')

# Known labels across the dataset
LABELS = ['walking', 'jogging', 'sitting', 'standing', 'upstairs', 'downstairs',
          'no freeze', 'freeze', 'normal', 'abnormal', 'positive', 'negative',
          'supraventricular', 'premature ventricular', 'fusion', 'unclassifiable',
          'atrial premature', 'premature ventricular contraction', 'right bundle branch block',
          'left bundle branch block', 'paced']
# extract the last label of the sentence
def extract_label(text):
    text = str(text).lower() # converts everything to lowercase
    # Find the last occurrence of a known label
    best = None
    best_pos = -1
    for label in sorted(LABELS, key=len, reverse=True):  # longest first, prevents "ventricular" from being caught when the full label is actually "premature ventricular."
        pos = text.rfind(label) # rfind(): returns the index where is string is found. If not found, it returns -1
        if pos != -1 and pos > best_pos: # If a label is found later in the text than any previously found label, the script "overwrites" the old one
            best_pos = pos
            best = label
    return best

correct = 0
total = len(df)
mismatches = []
for i, row in df.iterrows():
    qa = str(row['QA_list'])
    # Extract answer portion
    ans_match = re.search(r'answer.*?[:,]\s*["\s]*(.*?)["\s]*$', qa, re.IGNORECASE | re.DOTALL) # regular expression
    true_text = ans_match.group(1) if ans_match else qa

    true_label = extract_label(true_text)
    model_label = extract_label(str(row['model_response']))

    if true_label and model_label and true_label == model_label:
        correct += 1
    else:
        if len(mismatches) < 5:
            mismatches.append((i, true_label, model_label, str(row['model_response'])[:100]))

print(f"Correct: {correct}/{total}")
print(f"Accuracy: {correct/total*100:.2f}%")
print(f"\nSample mismatches:")
for idx, t, m, resp in mismatches:
    print(f"  Row {idx}: true='{t}' vs model='{m}'")

# Check for any None labels
none_true = sum(1 for _, row in df.iterrows() if extract_label(str(row['QA_list'])) is None)
none_model = sum(1 for _, row in df.iterrows() if extract_label(str(row['model_response'])) is None)
print(f"\nUnparsed true labels: {none_true}, Unparsed model labels: {none_model}")
if none_model > 0:
    for i, row in df.iterrows():
        if extract_label(str(row['model_response'])) is None:
            print(f"  Row {i} model_response: {str(row['model_response'])[:200]}")
# Out:
# Correct: 288/400
# Accuracy: 72.00%
#
# Sample mismatches:
#   Row 0: true='sitting' vs model='walking'
#   Row 4: true='upstairs' vs model='walking'
#   Row 8: true='jogging' vs model='walking'
#   Row 9: true='jogging' vs model='walking'
#   Row 14: true='downstairs' vs model='walking'
#
# Unparsed true labels: 0, Unparsed model labels: 0

# %% [markdown]
# ## Anomaly Detection

# %%
import pandas as pd
import re

df = pd.read_csv('/content/drive/My Drive/CADE/results/qwen3-0.6B+lora/results_anomaly.csv')
print(f"Total rows: {len(df)}")

def extract_label(text):
    """Extract anomaly detection label: 'normal' or 'anomaly'."""
    text = str(text).lower()
    if 'no anomaly' in text or 'normal point' in text or 'no anomalies' in text:
        return 'normal'
    if 'anomaly point' in text or 'anomaly' in text or 'anomalies' in text:
        return 'anomaly'
    return None

correct = 0
total = len(df)
mismatches = []
for i, row in df.iterrows():
    qa = str(row['QA_list'])
    # Extract answer portion from QA_list
    ans_match = re.search(r'answer.*?[:,]\s*["\s]*(.*?)["\s]*$', qa, re.IGNORECASE | re.DOTALL)
    true_text = ans_match.group(1) if ans_match else qa

    true_label = extract_label(true_text)
    model_label = extract_label(str(row['model_response']))

    if true_label and model_label and true_label == model_label:
        correct += 1
    else:
        mismatches.append((i, true_label, model_label))

print(f"Correct: {correct}/{total}")
print(f"Accuracy: {correct/total*100:.2f}%")
print(f"\nMismatches ({len(mismatches)}):")
for idx, t, m in mismatches:
    print(f"  Row {idx}: true='{t}' vs model='{m}'")
# Out:
# Total rows: 400
# Correct: 239/400
# Accuracy: 59.75%
#
# Mismatches (161):
#   Row 0: true='normal' vs model='anomaly'
#   Row 1: true='anomaly' vs model='normal'
#   Row 4: true='anomaly' vs model='normal'
#   Row 5: true='normal' vs model='anomaly'
#   Row 6: true='anomaly' vs model='normal'
#   Row 7: true='anomaly' vs model='normal'
#   Row 8: true='normal' vs model='anomaly'
#   Row 10: true='normal' vs model='anomaly'
#   Row 11: true='anomaly' vs model='normal'
#   Row 12: true='normal' vs model='anomaly'
#   Row 14: true='normal' vs model='anomaly'
#   Row 15: true='normal' vs model='anomaly'
#   Row 17: true='anomaly' vs model='normal'
#   Row 19: true='anomaly' vs model='normal'
#   Row 25: true='normal' vs model='anomaly'
#   Row 26: true='anomaly' vs model='normal'
#   Row 28: true='normal' vs model='anomaly'
#   Row 32: true='normal' vs model='anomaly'
#   Row 33: true='normal' vs model='anomaly'
#   Row 37: true='normal' vs model='anomaly'
#   Row 38: true='normal' vs model='anomaly'
#   Row 39: true='normal' vs model='anomaly'
#   Row 40: true='normal' vs model='anomaly'
#   Row 42: true='normal' vs model='anomaly'
#   Row 45: true='anomaly' vs model='normal'
#   Row 48: true='normal' vs model='anomaly'
#   Row 55: true='normal' vs model='anomaly'
#   Row 57: true='normal' vs model='anomaly'
#   Row 59: true='normal' vs model='anomaly'
#   Row 61: true='anomaly' vs model='normal'
#   Row 63: true='normal' vs model='anomaly'
#   Row 64: true='normal' vs model='anomaly'
#   Row 65: true='normal' vs model='anomaly'
#   Row 70: true='normal' vs model='anomaly'
#   Row 73: true='normal' vs model='anomaly'
#   Row 75: true='anomaly' vs model='normal'
#   Row 77: true='anomaly' vs model='normal'
#   Row 79: true='normal' vs model='anomaly'
#   Row 89: true='normal' vs model='anomaly'
#   Row 90: true='normal' vs model='anomaly'
#   Row 92: true='normal' vs model='anomaly'
#   Row 94: true='normal' vs model='anomaly'
#   Row 95: true='normal' vs model='anomaly'
#   Row 96: true='normal' vs model='anomaly'
#   Row 98: true='normal' vs model='anomaly'
#   Row 102: true='normal' vs model='anomaly'
#   Row 103: true='normal' vs model='anomaly'
#   Row 105: true='anomaly' vs model='normal'
#   Row 108: true='normal' vs model='anomaly'
#   Row 109: true='normal' vs model='anomaly'
#   Row 112: true='normal' vs model='anomaly'
#   Row 113: true='normal' vs model='anomaly'
#   Row 116: true='normal' vs model='anomaly'
#   Row 120: true='anomaly' vs model='normal'
#   Row 123: true='normal' vs model='anomaly'
#   Row 126: true='normal' vs model='anomaly'
#   Row 127: true='normal' vs model='anomaly'
#   Row 130: true='anomaly' vs model='normal'
#   Row 137: true='normal' vs model='anomaly'
#   Row 138: true='normal' vs model='anomaly'
#   Row 145: true='anomaly' vs model='normal'
#   Row 146: true='anomaly' vs model='normal'
#   Row 150: true='normal' vs model='anomaly'
#   Row 154: true='anomaly' vs model='normal'
#   Row 156: true='normal' vs model='anomaly'
#   Row 157: true='normal' vs model='anomaly'
#   Row 163: true='anomaly' vs model='normal'
#   Row 164: true='normal' vs model='anomaly'
#   Row 165: true='normal' vs model='anomaly'
#   Row 168: true='normal' vs model='anomaly'
#   Row 173: true='anomaly' vs model='normal'
#   Row 175: true='normal' vs model='anomaly'
#   Row 177: true='normal' vs model='anomaly'
#   Row 181: true='anomaly' vs model='normal'
#   Row 183: true='normal' vs model='anomaly'
#   Row 184: true='normal' vs model='anomaly'
#   Row 186: true='normal' vs model='anomaly'
#   Row 188: true='normal' vs model='anomaly'
#   Row 190: true='normal' vs model='anomaly'
#   Row 203: true='normal' vs model='anomaly'
#   Row 204: true='normal' vs model='anomaly'
#   Row 206: true='normal' vs model='anomaly'
#   Row 207: true='anomaly' vs model='normal'
#   Row 209: true='anomaly' vs model='normal'
#   Row 213: true='normal' vs model='anomaly'
#   Row 214: true='normal' vs model='anomaly'
#   Row 222: true='normal' vs model='anomaly'
#   Row 223: true='anomaly' vs model='normal'
#   Row 224: true='normal' vs model='anomaly'
#   Row 227: true='anomaly' vs model='normal'
#   Row 228: true='normal' vs model='anomaly'
#   Row 229: true='normal' vs model='anomaly'
#   Row 230: true='anomaly' vs model='normal'
#   Row 231: true='normal' vs model='anomaly'
#   Row 237: true='normal' vs model='anomaly'
#   Row 240: true='normal' vs model='anomaly'
#   Row 241: true='anomaly' vs model='normal'
#   Row 244: true='normal' vs model='anomaly'
#   Row 248: true='normal' vs model='anomaly'
#   Row 250: true='normal' vs model='anomaly'
#   Row 256: true='normal' vs model='anomaly'
#   Row 258: true='anomaly' vs model='normal'
#   Row 266: true='anomaly' vs model='normal'
#   Row 267: true='normal' vs model='anomaly'
#   Row 270: true='anomaly' vs model='normal'
#   Row 271: true='anomaly' vs model='normal'
#   Row 274: true='anomaly' vs model='normal'
#   Row 275: true='normal' vs model='anomaly'
#   Row 278: true='anomaly' vs model='normal'
#   Row 280: true='normal' vs model='anomaly'
#   Row 282: true='normal' vs model='anomaly'
#   Row 284: true='normal' vs model='anomaly'
#   Row 286: true='normal' vs model='anomaly'
#   Row 288: true='normal' vs model='anomaly'
#   Row 289: true='normal' vs model='anomaly'
#   Row 294: true='normal' vs model='anomaly'
#   Row 296: true='normal' vs model='anomaly'
#   Row 299: true='anomaly' vs model='normal'
#   Row 301: true='normal' vs model='anomaly'
#   Row 307: true='normal' vs model='anomaly'
#   Row 308: true='normal' vs model='anomaly'
#   Row 309: true='anomaly' vs model='normal'
#   Row 310: true='anomaly' vs model='normal'
#   Row 311: true='anomaly' vs model='normal'
#   Row 312: true='normal' vs model='anomaly'
#   Row 314: true='normal' vs model='anomaly'
#   Row 315: true='anomaly' vs model='normal'
#   Row 316: true='anomaly' vs model='normal'
#   Row 319: true='anomaly' vs model='normal'
#   Row 320: true='anomaly' vs model='normal'
#   Row 325: true='normal' vs model='anomaly'
#   Row 327: true='anomaly' vs model='normal'
#   Row 328: true='normal' vs model='anomaly'
#   Row 329: true='normal' vs model='anomaly'
#   Row 331: true='normal' vs model='anomaly'
#   Row 333: true='anomaly' vs model='normal'
#   Row 340: true='anomaly' vs model='normal'
#   Row 341: true='normal' vs model='anomaly'
#   Row 343: true='normal' vs model='anomaly'
#   Row 344: true='normal' vs model='anomaly'
#   Row 345: true='normal' vs model='anomaly'
#   Row 346: true='anomaly' vs model='normal'
#   Row 347: true='anomaly' vs model='normal'
#   Row 353: true='anomaly' vs model='normal'
#   Row 355: true='normal' vs model='anomaly'
#   Row 357: true='normal' vs model='anomaly'
#   Row 358: true='normal' vs model='anomaly'
#   Row 359: true='normal' vs model='anomaly'
#   Row 367: true='anomaly' vs model='normal'
#   Row 373: true='anomaly' vs model='normal'
#   Row 375: true='normal' vs model='anomaly'
#   Row 378: true='normal' vs model='anomaly'
#   Row 381: true='anomaly' vs model='normal'
#   Row 382: true='normal' vs model='anomaly'
#   Row 383: true='anomaly' vs model='normal'
#   Row 384: true='anomaly' vs model='normal'
#   Row 385: true='normal' vs model='anomaly'
#   Row 390: true='normal' vs model='anomaly'
#   Row 392: true='anomaly' vs model='normal'
#   Row 397: true='anomaly' vs model='normal'
#   Row 399: true='normal' vs model='anomaly'

# %% [markdown]
# ## Multiple Choice

# %%
import pandas as pd
import re

df = pd.read_csv('/content/drive/My Drive/CADE/results/qwen3-0.6B+lora/results_multiple_choice.csv')
print(f"Total rows: {len(df)}")

def extract_choice(text):
    """Extract multiple choice answer (A/B/C/D or True/False) from text."""
    text = str(text).strip()
    # Match leading letter choice like "A)", "a)", "B.", "C)" etc.
    m = re.match(r'^([A-Da-d])[).\s]', text) #
    if m:
        return m.group(1).upper() # catch the first parentheses of m (e.g., "b") and converts any lowercase letter to uppercase
    # "Answer: (b)" or "answer is (A)" or "option (c)"
    m = re.search(r'(?:answer|option)[:\s]+\(?([A-Da-d])\)?', text, re.IGNORECASE)
    if m:
        return m.group(1).upper()
    # "The answer is (A)"
    m = re.search(r'the answer is\s*\(?([A-Da-d])\)?', text, re.IGNORECASE)
    if m:
        return m.group(1).upper()
    # True/False style answers in multiple choice
    if re.match(r'^true', text, re.IGNORECASE):
        return 'TRUE'
    if re.match(r'^false', text, re.IGNORECASE):
        return 'FALSE'
    # Last resort: find first standalone letter with parentheses. Like (A, B, C, or D) or (a, b, c, d)
    m = re.search(r'\(([A-Da-d])\)', text)
    if m:
        return m.group(1).upper()
    return None

correct = 0
total = len(df)
mismatches = []
unparsed = []
for i, row in df.iterrows():
    qa = str(row['QA_list'])
    # Extract answer portion from QA_list
    ans_match = re.search(r'answer.*?[:,]\s*["\s]*(.*?)["\s]*$', qa, re.IGNORECASE | re.DOTALL)
    true_text = ans_match.group(1) if ans_match else qa

    true_label = extract_choice(true_text)
    model_label = extract_choice(str(row['model_response']))

    if true_label and model_label and true_label == model_label:
        correct += 1
    else:
        mismatches.append((i, true_label, model_label))
    if model_label is None:
        unparsed.append((i, str(row['model_response'])[:150]))

print(f"Correct: {correct}/{total}")
print(f"Accuracy: {correct/total*100:.2f}%")
print(f"\nMismatches ({len(mismatches)}):")
for idx, t, m in mismatches:
    print(f"  Row {idx}: true='{t}' vs model='{m}'")
if unparsed:
    print(f"\nUnparsed model responses ({len(unparsed)}):")
    for idx, r in unparsed:
        print(f"  Row {idx}: {r}")
# Out:
# Total rows: 397
# Correct: 187/397
# Accuracy: 47.10%
#
# Mismatches (210):
#   Row 3: true='A' vs model='B'
#   Row 4: true='C' vs model='B'
#   Row 5: true='C' vs model='B'
#   Row 7: true='D' vs model='C'
#   Row 9: true='A' vs model='B'
#   Row 10: true='A' vs model='B'
#   Row 14: true='B' vs model='FALSE'
#   Row 16: true='None' vs model='FALSE'
#   Row 18: true='A' vs model='B'
#   Row 19: true='D' vs model='B'
#   Row 20: true='A' vs model='B'
#   Row 21: true='A' vs model='B'
#   Row 22: true='C' vs model='A'
#   Row 23: true='B' vs model='C'
#   Row 25: true='A' vs model='B'
#   Row 27: true='D' vs model='C'
#   Row 29: true='None' vs model='A'
#   Row 30: true='A' vs model='B'
#   Row 32: true='A' vs model='B'
#   Row 33: true='A' vs model='B'
#   Row 34: true='B' vs model='A'
#   Row 37: true='A' vs model='B'
#   Row 38: true='A' vs model='B'
#   Row 40: true='B' vs model='A'
#   Row 42: true='B' vs model='C'
#   Row 45: true='A' vs model='B'
#   Row 47: true='A' vs model='B'
#   Row 48: true='B' vs model='A'
#   Row 49: true='B' vs model='D'
#   Row 50: true='C' vs model='A'
#   Row 52: true='A' vs model='B'
#   Row 54: true='C' vs model='B'
#   Row 55: true='C' vs model='A'
#   Row 59: true='A' vs model='B'
#   Row 62: true='B' vs model='A'
#   Row 63: true='D' vs model='B'
#   Row 65: true='C' vs model='B'
#   Row 67: true='C' vs model='B'
#   Row 70: true='A' vs model='B'
#   Row 71: true='C' vs model='A'
#   Row 73: true='B' vs model='A'
#   Row 76: true='D' vs model='A'
#   Row 79: true='C' vs model='B'
#   Row 80: true='A' vs model='B'
#   Row 82: true='None' vs model='FALSE'
#   Row 83: true='A' vs model='B'
#   Row 84: true='B' vs model='FALSE'
#   Row 86: true='None' vs model='A'
#   Row 88: true='C' vs model='B'
#   Row 89: true='B' vs model='A'
#   Row 91: true='C' vs model='A'
#   Row 92: true='B' vs model='C'
#   Row 93: true='B' vs model='C'
#   Row 95: true='A' vs model='B'
#   Row 97: true='None' vs model='None'
#   Row 99: true='D' vs model='A'
#   Row 104: true='A' vs model='C'
#   Row 105: true='B' vs model='A'
#   Row 111: true='C' vs model='A'
#   Row 112: true='C' vs model='A'
#   Row 113: true='B' vs model='A'
#   Row 116: true='A' vs model='B'
#   Row 118: true='A' vs model='B'
#   Row 119: true='B' vs model='C'
#   Row 121: true='C' vs model='A'
#   Row 122: true='A' vs model='B'
#   Row 126: true='D' vs model='A'
#   Row 127: true='D' vs model='None'
#   Row 128: true='A' vs model='B'
#   Row 130: true='None' vs model='None'
#   Row 131: true='C' vs model='A'
#   Row 135: true='B' vs model='C'
#   Row 136: true='B' vs model='C'
#   Row 139: true='A' vs model='B'
#   Row 140: true='A' vs model='B'
#   Row 142: true='C' vs model='B'
#   Row 143: true='A' vs model='B'
#   Row 144: true='C' vs model='B'
#   Row 145: true='C' vs model='B'
#   Row 146: true='C' vs model='B'
#   Row 148: true='C' vs model='B'
#   Row 152: true='B' vs model='A'
#   Row 154: true='C' vs model='B'
#   Row 155: true='A' vs model='B'
#   Row 157: true='B' vs model='C'
#   Row 163: true='B' vs model='A'
#   Row 164: true='D' vs model='C'
#   Row 165: true='A' vs model='B'
#   Row 167: true='C' vs model='B'
#   Row 171: true='D' vs model='A'
#   Row 173: true='None' vs model='B'
#   Row 176: true='C' vs model='B'
#   Row 178: true='A' vs model='B'
#   Row 180: true='None' vs model='None'
#   Row 181: true='A' vs model='B'
#   Row 182: true='D' vs model='B'
#   Row 186: true='C' vs model='B'
#   Row 191: true='A' vs model='B'
#   Row 192: true='None' vs model='A'
#   Row 200: true='A' vs model='B'
#   Row 201: true='C' vs model='A'
#   Row 202: true='A' vs model='C'
#   Row 203: true='C' vs model='B'
#   Row 205: true='A' vs model='B'
#   Row 206: true='A' vs model='B'
#   Row 207: true='None' vs model='None'
#   Row 208: true='None' vs model='FALSE'
#   Row 212: true='A' vs model='B'
#   Row 215: true='A' vs model='D'
#   Row 216: true='A' vs model='B'
#   Row 217: true='A' vs model='B'
#   Row 218: true='B' vs model='C'
#   Row 220: true='C' vs model='B'
#   Row 223: true='None' vs model='FALSE'
#   Row 224: true='B' vs model='A'
#   Row 225: true='A' vs model='B'
#   Row 226: true='C' vs model='A'
#   Row 227: true='A' vs model='B'
#   Row 229: true='D' vs model='B'
#   Row 230: true='C' vs model='A'
#   Row 232: true='A' vs model='B'
#   Row 233: true='C' vs model='B'
#   Row 236: true='D' vs model='A'
#   Row 237: true='D' vs model='B'
#   Row 238: true='D' vs model='B'
#   Row 239: true='D' vs model='A'
#   Row 240: true='D' vs model='A'
#   Row 241: true='C' vs model='A'
#   Row 242: true='A' vs model='B'
#   Row 243: true='A' vs model='C'
#   Row 246: true='C' vs model='B'
#   Row 247: true='D' vs model='C'
#   Row 254: true='C' vs model='A'
#   Row 258: true='A' vs model='B'
#   Row 261: true='A' vs model='B'
#   Row 262: true='C' vs model='B'
#   Row 265: true='D' vs model='B'
#   Row 266: true='D' vs model='C'
#   Row 271: true='C' vs model='B'
#   Row 272: true='B' vs model='A'
#   Row 274: true='D' vs model='C'
#   Row 275: true='None' vs model='C'
#   Row 276: true='B' vs model='C'
#   Row 279: true='C' vs model='B'
#   Row 280: true='B' vs model='FALSE'
#   Row 281: true='A' vs model='B'
#   Row 283: true='A' vs model='B'
#   Row 284: true='C' vs model='B'
#   Row 285: true='C' vs model='A'
#   Row 288: true='A' vs model='C'
#   Row 289: true='A' vs model='B'
#   Row 292: true='A' vs model='B'
#   Row 293: true='C' vs model='B'
#   Row 294: true='A' vs model='C'
#   Row 297: true='A' vs model='B'
#   Row 299: true='C' vs model='A'
#   Row 300: true='None' vs model='None'
#   Row 303: true='C' vs model='B'
#   Row 304: true='C' vs model='A'
#   Row 306: true='A' vs model='B'
#   Row 311: true='C' vs model='A'
#   Row 312: true='C' vs model='B'
#   Row 313: true='A' vs model='B'
#   Row 314: true='B' vs model='C'
#   Row 316: true='A' vs model='B'
#   Row 319: true='C' vs model='B'
#   Row 320: true='C' vs model='B'
#   Row 321: true='C' vs model='B'
#   Row 322: true='C' vs model='B'
#   Row 323: true='A' vs model='C'
#   Row 325: true='C' vs model='B'
#   Row 326: true='A' vs model='B'
#   Row 327: true='A' vs model='B'
#   Row 328: true='B' vs model='D'
#   Row 329: true='C' vs model='B'
#   Row 334: true='B' vs model='A'
#   Row 335: true='B' vs model='A'
#   Row 336: true='A' vs model='C'
#   Row 340: true='A' vs model='B'
#   Row 342: true='D' vs model='C'
#   Row 344: true='A' vs model='B'
#   Row 345: true='C' vs model='B'
#   Row 346: true='B' vs model='C'
#   Row 347: true='D' vs model='A'
#   Row 348: true='D' vs model='B'
#   Row 349: true='A' vs model='B'
#   Row 350: true='C' vs model='A'
#   Row 353: true='C' vs model='B'
#   Row 354: true='A' vs model='None'
#   Row 355: true='B' vs model='A'
#   Row 356: true='A' vs model='B'
#   Row 357: true='A' vs model='B'
#   Row 359: true='C' vs model='A'
#   Row 360: true='B' vs model='A'
#   Row 365: true='A' vs model='B'
#   Row 370: true='D' vs model='A'
#   Row 371: true='A' vs model='B'
#   Row 373: true='B' vs model='A'
#   Row 374: true='B' vs model='C'
#   Row 377: true='C' vs model='B'
#   Row 378: true='C' vs model='A'
#   Row 379: true='A' vs model='B'
#   Row 381: true='D' vs model='B'
#   Row 382: true='C' vs model='B'
#   Row 383: true='A' vs model='B'
#   Row 387: true='C' vs model='B'
#   Row 390: true='C' vs model='B'
#   Row 392: true='D' vs model='A'
#   Row 394: true='B' vs model='A'
#   Row 396: true='C' vs model='B'
#
# Unparsed model responses (7):
#   Row 97: Based on the data provided, the mean is 0.75.
#   Row 127: Based on the given data, the value -2894.61 is an anomaly. It is significantly lower than the surrounding data points, indicating a potential outlier
#   Row 130: Answer: 24.78. Reasoning: The data points show a general downward trend, but 24.78 is significantly higher than the surrounding values, indicating it
#   Row 180: Option: 2435.55. The mean is calculated by summing all the data points and dividing by the number of points. Sum = 48638.09, Number of points = 24, Me
#   Row 207: 0.34, 0.42, 0.35, 0.65, 0.89, 0.7. The first set shows more variability with larger fluctuations, whereas the second set has a more consistent pattern
#   Row 300: Answer: -8403.38. This value is significantly lower than the other data points, indicating it is an outlier in the context of the healthcare applicati
#   Row 354: B: -2220. The data shows a clear downward trend, and the last point is -2224.76, indicating a continuation of the downward movement.

# %% [markdown]
# ## True/False Question

# %%
import pandas as pd
import re

df = pd.read_csv('/content/drive/My Drive/CADE/results/qwen3-0.6B+lora/results_true_false.csv')
print(f"Total rows: {len(df)}")

def extract_tf(text):
    """Extract True/False label from text."""
    text = str(text).strip().lower()
    # Check the leading word first
    if re.match(r'^(true|yes)', text):
        return 'true'
    if re.match(r'^(false|no[^a-z])', text):
        return 'false'
    # Fallback: search anywhere (only if unambiguous)
    if 'true' in text and 'false' not in text:
        return 'true'
    if 'false' in text and 'true' not in text:
        return 'false'
    return None

correct = 0
total = len(df)
mismatches = []
for i, row in df.iterrows():
    qa = str(row['QA_list'])
    # Extract answer portion from QA_list
    ans_match = re.search(r'answer.*?[:,]\s*["\s]*(.*?)["\s]*$', qa, re.IGNORECASE | re.DOTALL)
    true_text = ans_match.group(1) if ans_match else qa

    true_label = extract_tf(true_text)
    model_label = extract_tf(str(row['model_response']))

    if true_label and model_label and true_label == model_label:
        correct += 1
    else:
        mismatches.append((i, true_label, model_label))

print(f"Correct: {correct}/{total}")
print(f"Accuracy: {correct/total*100:.2f}%")
print(f"\nMismatches ({len(mismatches)}):")
for idx, t, m in mismatches:
    print(f"  Row {idx}: true='{t}' vs model='{m}'")
# Out:
# Total rows: 400
# Correct: 271/400
# Accuracy: 67.75%
#
# Mismatches (129):
#   Row 2: true='true' vs model='false'
#   Row 5: true='true' vs model='false'
#   Row 7: true='true' vs model='false'
#   Row 8: true='true' vs model='false'
#   Row 13: true='false' vs model='true'
#   Row 14: true='true' vs model='false'
#   Row 15: true='true' vs model='false'
#   Row 22: true='true' vs model='false'
#   Row 25: true='true' vs model='false'
#   Row 40: true='true' vs model='false'
#   Row 42: true='false' vs model='true'
#   Row 44: true='true' vs model='false'
#   Row 46: true='true' vs model='false'
#   Row 49: true='false' vs model='true'
#   Row 54: true='true' vs model='false'
#   Row 55: true='true' vs model='false'
#   Row 57: true='true' vs model='false'
#   Row 67: true='true' vs model='false'
#   Row 71: true='true' vs model='false'
#   Row 79: true='true' vs model='false'
#   Row 81: true='true' vs model='false'
#   Row 88: true='true' vs model='false'
#   Row 91: true='false' vs model='true'
#   Row 92: true='true' vs model='false'
#   Row 94: true='true' vs model='false'
#   Row 96: true='true' vs model='false'
#   Row 98: true='true' vs model='false'
#   Row 99: true='true' vs model='false'
#   Row 103: true='true' vs model='false'
#   Row 104: true='true' vs model='false'
#   Row 106: true='true' vs model='false'
#   Row 108: true='true' vs model='false'
#   Row 119: true='false' vs model='true'
#   Row 123: true='true' vs model='false'
#   Row 125: true='true' vs model='false'
#   Row 131: true='true' vs model='false'
#   Row 132: true='true' vs model='false'
#   Row 133: true='false' vs model='true'
#   Row 134: true='true' vs model='false'
#   Row 137: true='false' vs model='true'
#   Row 139: true='true' vs model='false'
#   Row 145: true='true' vs model='false'
#   Row 146: true='true' vs model='false'
#   Row 148: true='true' vs model='false'
#   Row 157: true='true' vs model='false'
#   Row 160: true='true' vs model='false'
#   Row 167: true='true' vs model='false'
#   Row 172: true='true' vs model='false'
#   Row 177: true='true' vs model='false'
#   Row 180: true='true' vs model='false'
#   Row 181: true='true' vs model='false'
#   Row 182: true='false' vs model='true'
#   Row 186: true='false' vs model='true'
#   Row 187: true='true' vs model='false'
#   Row 190: true='false' vs model='true'
#   Row 192: true='true' vs model='false'
#   Row 193: true='true' vs model='false'
#   Row 196: true='false' vs model='true'
#   Row 200: true='true' vs model='false'
#   Row 202: true='true' vs model='false'
#   Row 204: true='true' vs model='false'
#   Row 212: true='true' vs model='false'
#   Row 213: true='true' vs model='false'
#   Row 215: true='true' vs model='false'
#   Row 216: true='true' vs model='false'
#   Row 217: true='true' vs model='false'
#   Row 221: true='true' vs model='false'
#   Row 224: true='true' vs model='false'
#   Row 226: true='true' vs model='false'
#   Row 229: true='true' vs model='false'
#   Row 230: true='true' vs model='false'
#   Row 232: true='true' vs model='false'
#   Row 234: true='true' vs model='false'
#   Row 235: true='true' vs model='false'
#   Row 236: true='true' vs model='false'
#   Row 241: true='false' vs model='true'
#   Row 243: true='true' vs model='false'
#   Row 249: true='true' vs model='false'
#   Row 250: true='true' vs model='false'
#   Row 255: true='true' vs model='false'
#   Row 262: true='false' vs model='true'
#   Row 265: true='true' vs model='false'
#   Row 267: true='true' vs model='false'
#   Row 268: true='true' vs model='false'
#   Row 269: true='true' vs model='false'
#   Row 271: true='true' vs model='false'
#   Row 275: true='true' vs model='false'
#   Row 276: true='true' vs model='false'
#   Row 278: true='true' vs model='false'
#   Row 280: true='true' vs model='false'
#   Row 282: true='true' vs model='false'
#   Row 283: true='true' vs model='false'
#   Row 287: true='true' vs model='false'
#   Row 290: true='true' vs model='false'
#   Row 291: true='true' vs model='false'
#   Row 292: true='true' vs model='false'
#   Row 302: true='true' vs model='false'
#   Row 305: true='true' vs model='false'
#   Row 310: true='true' vs model='false'
#   Row 313: true='true' vs model='false'
#   Row 316: true='true' vs model='false'
#   Row 324: true='true' vs model='false'
#   Row 325: true='true' vs model='false'
#   Row 326: true='true' vs model='false'
#   Row 327: true='false' vs model='true'
#   Row 329: true='true' vs model='false'
#   Row 330: true='true' vs model='false'
#   Row 332: true='true' vs model='false'
#   Row 333: true='true' vs model='false'
#   Row 334: true='true' vs model='false'
#   Row 336: true='true' vs model='false'
#   Row 340: true='true' vs model='false'
#   Row 341: true='true' vs model='false'
#   Row 346: true='true' vs model='false'
#   Row 348: true='true' vs model='false'
#   Row 356: true='true' vs model='false'
#   Row 360: true='true' vs model='false'
#   Row 361: true='true' vs model='false'
#   Row 366: true='true' vs model='false'
#   Row 368: true='true' vs model='false'
#   Row 371: true='true' vs model='false'
#   Row 372: true='true' vs model='false'
#   Row 373: true='true' vs model='false'
#   Row 374: true='true' vs model='false'
#   Row 377: true='true' vs model='false'
#   Row 378: true='true' vs model='false'
#   Row 382: true='false' vs model='true'
#   Row 391: true='true' vs model='false'
#   Row 399: true='true' vs model='false'

# %% [markdown]
# ## Forecasting

# %%
"""
Evaluation Script: MSE for Forecasting Task
=============================================
Computes Mean Squared Error between the true answer and model response
for time series forecasting results.

Input:  results_forecasting.csv
        - Column: QA_list     (contains the true answer list/value after "answer" key)
        - Column: model_response (contains the model's predicted list/value)

Output: MSE statistics printed to console.
"""

import csv
import re
import numpy as np


def extract_list_from_text(text):
    """Extract a list of floats from text containing a bracketed list like [1.0, 2.0, ...]."""
    match = re.search(r'\[([^\]]+)\]', text)
    if not match:
        return None
    items = match.group(1).split(',')
    result = []
    for item in items:
        item = item.strip().strip("'\"") # remove whitespace and '"
        try:
            result.append(float(item)) # transform into float
        except ValueError:
            result.append(None)
    return [x for x in result if x is not None] # remove the None value from list


def extract_single_number(text):
    """
    Fallback: extract a single numeric value from free-text responses.
    Used when the answer/response is a single predicted value rather than a list.
    """
    nums = re.findall(r'[-+]?\d*\.?\d+', text) # find numeric value
    if nums:
        return [float(nums[-1])] # extract and return the last numeric value
    return None


def parse_answer(qa_text):
    """Extract the answer from the QA_list column."""
    if '"answer"' not in qa_text:
        return None

    answer_part = qa_text.split('"answer"')[-1] # take the last part {"question": "...", "answer": "[1, 2, 3]"})

    # Try list extraction first
    answer_list = extract_list_from_text(answer_part)
    if answer_list and len(answer_list) > 0:
        return answer_list

    # Fallback: single number from the answer text
    ans_match = re.search(r'"answer".*?:\s*"(.*?)"', qa_text, re.DOTALL) # extract content after answer within ""
    if ans_match:
        return extract_single_number(ans_match.group(1))

    return None


def parse_model_response(model_text):
    """Extract the predicted values from the model_response column."""
    # Try list extraction first
    model_list = extract_list_from_text(model_text)
    if model_list and len(model_list) > 0:
        return model_list

    # Fallback: single number
    return extract_single_number(model_text)


def compute_mse_forecasting(csv_path):
    """
    Parse the forecasting CSV and compute MSE between answer and model_response.

    For each row:
      1. Extract the answer (list or single value) from the QA_list column.
      2. Extract the prediction (list or single value) from the model_response column.
      3. Align by index using min(len(answer), len(model)) to handle length mismatches.
      4. Compute squared errors for each aligned pair.

    Returns a dict with detailed statistics.
    """
    with open(csv_path, 'r') as f:
        reader = csv.reader(f)
        header = next(reader)

        all_squared_errors = []
        row_mses = []
        row_details = []
        skipped_rows = []
        row_count = 0

        for row in reader:
            qa_text = row[2]       # QA_list column
            model_text = row[7]    # model_response column

            # --- Extract answer and model response ---
            answer_list = parse_answer(qa_text)
            model_list = parse_model_response(model_text)

            # --- Validate ---
            if answer_list is None or model_list is None:
                skipped_rows.append((row_count, "Could not parse list(s)"))
                row_count += 1
                continue

            if len(answer_list) == 0 or len(model_list) == 0:
                skipped_rows.append((row_count, "Empty list after parsing"))
                row_count += 1
                continue

            # --- Compute squared errors (aligned by position) ---
            min_len = min(len(answer_list), len(model_list))
            se = [(answer_list[i] - model_list[i]) ** 2 for i in range(min_len)]
            row_mse = np.mean(se)

            row_mses.append(row_mse)
            all_squared_errors.extend(se)
            row_details.append((row_count, len(answer_list), len(model_list), row_mse))

            row_count += 1

    # --- Aggregate statistics ---
    results = {
        "total_rows": row_count,
        "rows_used": len(row_mses),
        "rows_skipped": len(skipped_rows),
        "total_value_pairs": len(all_squared_errors),
        "mse_all_pairs": float(np.mean(all_squared_errors)) if all_squared_errors else None,
        "mse_avg_per_row": float(np.mean(row_mses)) if row_mses else None,
        "row_details": row_details,
        "skipped_rows": skipped_rows,
    }

    # Matched-length subset
    matched = [d for d in row_details if d[1] == d[2]]
    results["rows_matched_length"] = len(matched)
    results["mse_matched_length"] = float(np.mean([d[3] for d in matched])) if matched else None

    return results


def print_report(results):
    """Pretty-print the evaluation report."""
    print("=" * 60)
    print("  FORECASTING MSE EVALUATION REPORT")
    print("=" * 60)
    print(f"  Total rows in CSV:          {results['total_rows']}")
    print(f"  Rows successfully parsed:   {results['rows_used']}")
    print(f"  Rows skipped (unparseable): {results['rows_skipped']}")
    print(f"  Total value pairs compared: {results['total_value_pairs']}")
    print("-" * 60)
    print(f"  MSE (all value pairs):      {results['mse_all_pairs']:.6f}")
    print(f"  MSE (avg of per-row MSEs):  {results['mse_avg_per_row']:.6f}")
    print("-" * 60)
    print(f"  Rows with matching lengths: {results['rows_matched_length']}/{results['rows_used']}")
    if results['mse_matched_length'] is not None:
        print(f"  MSE (matched-length only):  {results['mse_matched_length']:.6f}")
    print("=" * 60)

    # Top 10 rows by MSE
    sorted_rows = sorted(results['row_details'], key=lambda x: x[3], reverse=True)
    print("\n  Top 10 rows by per-row MSE:")
    print(f"  {'Row':<6} {'Ans Len':<10} {'Model Len':<10} {'Row MSE':>15}")
    print("  " + "-" * 45)
    for r, alen, mlen, mse in sorted_rows[:10]:
        flag = " *" if alen != mlen else ""
        print(f"  {r:<6} {alen:<10} {mlen:<10} {mse:>15.4f}{flag}")
    print("  (* = length mismatch)")

    # Skipped rows
    if results['skipped_rows']:
        print(f"\n  Skipped rows:")
        for idx, reason in results['skipped_rows']:
            print(f"    Row {idx}: {reason}")


if __name__ == "__main__":
    CSV_PATH = "/content/drive/My Drive/CADE/results/qwen3-0.6B+lora/results_forecasting.csv"
    results = compute_mse_forecasting(CSV_PATH)
    print_report(results)
# Out:
# ============================================================
#   FORECASTING MSE EVALUATION REPORT
# ============================================================
#   Total rows in CSV:          379
#   Rows successfully parsed:   377
#   Rows skipped (unparseable): 2
#   Total value pairs compared: 7117
# ------------------------------------------------------------
#   MSE (all value pairs):      564752.201439
#   MSE (avg of per-row MSEs):  440626.667935
# ------------------------------------------------------------
#   Rows with matching lengths: 177/377
#   MSE (matched-length only):  54749.224453
# ============================================================
#
#   Top 10 rows by per-row MSE:
#   Row    Ans Len    Model Len          Row MSE
#   ---------------------------------------------
#   231    30         28           69116039.3571 *
#   43     28         27           33243319.0000 *
#   377    12         13           31304488.6667 *
#   291    32         28           13075416.7857 *
#   178    28         26            3725684.0769 *
#   94     26         26            3528629.1154
#   18     25         26            2422622.4400 *
#   311    11         11            1525129.9091
#   268    24         24            1395668.0000
#   152    18         18             989253.8889
#   (* = length mismatch)
#
#   Skipped rows:
#     Row 179: Could not parse list(s)
#     Row 303: Could not parse list(s)

# %% [markdown]
# ## Imputation

# %%
"""
Evaluation Script: MSE for Imputation Task
============================================
Computes Mean Squared Error between the true answer and model response
for time series imputation results.

Input:  results_imputation.csv
        - Column: QA_list     (contains the true answer list after "answer" key)
        - Column: model_response (contains the model's predicted list)

Output: MSE statistics printed to console.
"""

import csv
import re
import numpy as np


def extract_list_from_text(text):
    """Extract a list of floats from text containing a bracketed list like [1.0, 2.0, ...]."""
    match = re.search(r'\[([^\]]+)\]', text)
    if not match:
        return None
    items = match.group(1).split(',')
    result = []
    for item in items:
        item = item.strip().strip("'\"")
        try:
            result.append(float(item))
        except ValueError:
            result.append(None)  # e.g. 'X' or non-numeric tokens
    return [x for x in result if x is not None]


def compute_mse_imputation(csv_path):
    """
    Parse the imputation CSV and compute MSE between answer and model_response.

    For each row:
      1. Extract the answer list from the QA_list column (after the "answer" key).
      2. Extract the predicted list from the model_response column.
      3. Align by index using min(len(answer), len(model)) to handle length mismatches.
      4. Compute squared errors for each aligned pair.

    Returns a dict with detailed statistics.
    """
    with open(csv_path, 'r') as f:
        reader = csv.reader(f)
        header = next(reader)

        all_squared_errors = []   # every individual (answer_i - model_i)^2
        row_mses = []             # per-row MSE values
        row_details = []          # (row_index, answer_len, model_len, row_mse)
        skipped_rows = []         # rows that couldn't be parsed
        row_count = 0

        for row in reader:
            qa_text = row[2]       # QA_list column
            model_text = row[7]    # model_response column

            # --- Extract answer list ---
            answer_list = None
            if '"answer"' in qa_text:
                answer_part = qa_text.split('"answer"')[-1]
                answer_list = extract_list_from_text(answer_part)

            # --- Extract model response list ---
            model_list = extract_list_from_text(model_text)

            # --- Validate ---
            if answer_list is None or model_list is None:
                skipped_rows.append((row_count, "Could not parse list(s)"))
                row_count += 1
                continue

            if len(answer_list) == 0 or len(model_list) == 0:
                skipped_rows.append((row_count, "Empty list after parsing"))
                row_count += 1
                continue

            # --- Compute squared errors (aligned by position) ---
            min_len = min(len(answer_list), len(model_list))
            se = [(answer_list[i] - model_list[i]) ** 2 for i in range(min_len)]
            row_mse = np.mean(se)

            row_mses.append(row_mse)
            all_squared_errors.extend(se)
            row_details.append((row_count, len(answer_list), len(model_list), row_mse))

            row_count += 1

    # --- Aggregate statistics ---
    results = {
        "total_rows": row_count,
        "rows_used": len(row_mses),
        "rows_skipped": len(skipped_rows),
        "total_value_pairs": len(all_squared_errors),
        "mse_all_pairs": float(np.mean(all_squared_errors)) if all_squared_errors else None,
        "mse_avg_per_row": float(np.mean(row_mses)) if row_mses else None,
        "row_details": row_details,
        "skipped_rows": skipped_rows,
    }

    # Matched-length subset
    matched = [d for d in row_details if d[1] == d[2]]
    results["rows_matched_length"] = len(matched)
    results["mse_matched_length"] = float(np.mean([d[3] for d in matched])) if matched else None

    return results


def print_report(results):
    """Pretty-print the evaluation report."""
    print("=" * 60)
    print("  IMPUTATION MSE EVALUATION REPORT")
    print("=" * 60)
    print(f"  Total rows in CSV:          {results['total_rows']}")
    print(f"  Rows successfully parsed:   {results['rows_used']}")
    print(f"  Rows skipped (unparseable): {results['rows_skipped']}")
    print(f"  Total value pairs compared: {results['total_value_pairs']}")
    print("-" * 60)
    print(f"  MSE (all value pairs):      {results['mse_all_pairs']:.6f}")
    print(f"  MSE (avg of per-row MSEs):  {results['mse_avg_per_row']:.6f}")
    print("-" * 60)
    print(f"  Rows with matching lengths: {results['rows_matched_length']}/{results['rows_used']}")
    if results['mse_matched_length'] is not None:
        print(f"  MSE (matched-length only):  {results['mse_matched_length']:.6f}")
    print("=" * 60)

    # Top 10 rows by MSE
    sorted_rows = sorted(results['row_details'], key=lambda x: x[3], reverse=True)
    print("\n  Top 10 rows by per-row MSE:")
    print(f"  {'Row':<6} {'Ans Len':<10} {'Model Len':<10} {'Row MSE':>15}")
    print("  " + "-" * 45)
    for r, alen, mlen, mse in sorted_rows[:10]:
        flag = " *" if alen != mlen else ""
        print(f"  {r:<6} {alen:<10} {mlen:<10} {mse:>15.4f}{flag}")
    print("  (* = length mismatch)")

    # Skipped rows
    if results['skipped_rows']:
        print(f"\n  Skipped rows:")
        for idx, reason in results['skipped_rows']:
            print(f"    Row {idx}: {reason}")


if __name__ == "__main__":
    CSV_PATH = "/content/drive/My Drive/CADE/results/qwen3-0.6B+lora/results_imputation.csv"
    results = compute_mse_imputation(CSV_PATH)
    print_report(results)
# Out:
# ============================================================
#   IMPUTATION MSE EVALUATION REPORT
# ============================================================
#   Total rows in CSV:          400
#   Rows successfully parsed:   392
#   Rows skipped (unparseable): 8
#   Total value pairs compared: 66752
# ------------------------------------------------------------
#   MSE (all value pairs):      2607352.264041
#   MSE (avg of per-row MSEs):  2399043.284028
# ------------------------------------------------------------
#   Rows with matching lengths: 263/392
#   MSE (matched-length only):  3665.704353
# ============================================================
#
#   Top 10 rows by per-row MSE:
#   Row    Ans Len    Model Len          Row MSE
#   ---------------------------------------------
#   64     195        187         895843120.6631 *
#   12     142        128          13477981.1875 *
#   73     200        201           8447502.3800 *
#   8      113        112           7418561.6071 *
#   275    168        167           6514155.3473 *
#   56     105        104           2675893.9615 *
#   357    160        133           1668646.8120 *
#   187    178        177            917463.9548 *
#   133    200        199            481011.9246 *
#   299    116        115            440829.3391 *
#   (* = length mismatch)
#
#   Skipped rows:
#     Row 54: Could not parse list(s)
#     Row 66: Could not parse list(s)
#     Row 82: Could not parse list(s)
#     Row 179: Could not parse list(s)
#     Row 203: Could not parse list(s)
#     Row 244: Could not parse list(s)
#     Row 309: Could not parse list(s)
#     Row 376: Could not parse list(s)
